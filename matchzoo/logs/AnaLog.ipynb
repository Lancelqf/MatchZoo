# %%
import os
import sys

pytextnet_path='/home/yangzhou/lqf/MatchZoo/matchzoo/logs/'
sys.path.insert(0,pytextnet_path)
from logfig import *
#display plots in this notebook
# %matplotlib inline

# %%
log_data=[]
offset=0

log_data.append(generate_log_data('/home/yangzhou/lqf/MatchZoo/matchzoo/logs/mq2007/min_3.log',1,1,1))
log_data.append(generate_log_data('/home/yangzhou/lqf/MatchZoo/matchzoo/logs/mq2007/min_5.log',1,1,1))
draw_graph(1,log_data,'test','map',offset)
#draw_graph(1,log_data,'valid','map',offset)
#draw_graph(2,log_data,'test','ndcg@10',offset)
#draw_graph(2,log_data,'test','precision@10',offset)
# Out:
# /home/yangzhou/lqf/MatchZoo/matchzoo/logs/mq2007/min_3.log
# /home/yangzhou/lqf/MatchZoo/matchzoo/logs/mq2007/min_5.log
# average :  0.4132975
